# %% [markdown]
# <a href="https://colab.research.google.com/github/AkhilaSundalam-04/Innomatics-research-lab-Generative-AI-intership-task-1/blob/main/feb_intership_logic_building_task_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Problem 1: Smart Light Controller
class SmartLight:
    def __init__(self, name):
        self.name = name
        self.status = "OFF"

    def set_status(self, action):
        self.status = action

    def show(self):
        print(self.name, "is", self.status)


light = SmartLight("Bedroom Light")
light.set_status("ON")
light.show()

#Problem 2: Employee ID Card System
class Employee:
    def __init__(self, name, emp_id, dept):
        self.name = name
        self.emp_id = emp_id
        self.dept = dept

    def show(self):
        print("Employee ID Card")
        print("Name:", self.name)
        print("ID:", self.emp_id)
        print("Department:", self.dept)


e1 = Employee("Rahul", "EMP102", "IT")
e1.show()

#Problem 3: Mobile Contact Record
class Contact:
    def __init__(self, name, phone):
        self.name = name
        self.phone = phone

    def show(self):
        print("Contact Saved")
        print("Name:", self.name)
        print("Phone:", self.phone)


c1 = Contact("Anita", "9876543210")
c1.show()

#Problem 4: Product Price Tag Generator
class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price

    def show(self):
        print("Product:", self.name)
        print("Price: ₹" + str(self.price))


p1 = Product("Headphones", 2499)
p1.show()


#Problem 5: Movie Rating Display System
class Movie:
    def __init__(self, name, rating):
        self.name = name
        self.rating = rating

    def show(self):
        print("Movie:", self.name)
        print("Rating:", self.rating, "/ 5")


m1 = Movie("Inception", 4.8)
m1.show()

#Problem 6: Delivery Address Manager
class Delivery:
    def __init__(self, customer, address):
        self.customer = customer
        self.address = address

    def show(self):
        print("Delivery Details")
        print("Customer:", self.customer)
        print("Address:", self.address)


d1 = Delivery("Suman", "Hyderabad")
d1.show()
# Out:
# Bedroom Light is ON
# Employee ID Card
# Name: Rahul
# ID: EMP102
# Department: IT
# Contact Saved
# Name: Anita
# Phone: 9876543210
# Product: Headphones
# Price: ₹2499
# Movie: Inception
# Rating: 4.8 / 5
# Delivery Details
# Customer: Suman
# Address: Hyderabad
